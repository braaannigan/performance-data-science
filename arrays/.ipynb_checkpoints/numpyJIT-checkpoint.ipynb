# %% [markdown]
# ## Conditional loops through Numpy arrays with NumExpr and Numba
# We're going to look at a case where we are looking at a 2D numpy array and we're looking for the first value in each column that meets a condition.
#
# The example we're going to use

# %%
from pathlib import Path

import pandas as pd
import numba
import numexpr as ne
import numpy as np
import dask.array as da

import altair as alt

from IPython.display import Markdown, display
# %load_ext line_profiler

# %%
def printmd(string):
    display(Markdown(string))

# %%
dataPath = Path("../data/raw/")
interimDataPath = Path("../data/interim/")

def loadData(duplicateN:int=1):
    df = pd.read_csv(dataPath / "atlanticInterpolated.csv")
    z = df.z.values
    dropColumns = []
    for col in df.columns:
        if df.loc[30, col] > df.loc[0, col] - 0.1:
            dropColumns.append(col)
    df = df.drop(columns=dropColumns)
    df = pd.concat([df for _ in range(duplicateN)], axis=1)
    temps = df.iloc[:, 1:].values
    tempsC = np.ascontiguousarray(temps)
    surfaceTemps = temps[:2, :].mean(axis=0)
    surfaceTempsC = tempsC[:2, :].mean(axis=0)
    return df, temps, z, tempsC, surfaceTemps, surfaceTempsC

# %%
print("Load data")
df, temps, z, tempsC, surfaceTemps, surfaceTempsC = loadData(duplicateN=100)
print("Data loaded")
# Out:
# Load data
# Data loaded

# %%
thresholdTemperatureDifference = 0.1

# %%
surfaceTemps = temps[:2,:].mean(axis=0)
surfaceTempsC = tempsC[:2,:].mean(axis=0)
surfaceTemps.shape
# Out:
# (248299,)

# %%
# %timeit -n 1 -r 1 (temps < (surfaceTemps - thresholdTemperatureDifference)).nonzero()
# Out:
# 1.04 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
tempsDask = da.from_array(temps)
surfaceTempsDask = da.from_array(surfaceTemps)
condition = (tempsDask < (surfaceTempsDask - thresholdTemperatureDifference))
condition[:,0].nonzero()[0].compute()[0]
mldIndex = np.array(
        [condition[:,0].nonzero()[0].compute()[0] for colIdx in range(temps.shape[1])]
    )
mldIndex

# %%
(tempsDask < (surfaceTempsDask - thresholdTemperatureDifference)).nonzero()[0]
# Out:
# dask.array<getitem, shape=(nan,), dtype=int64, chunksize=(nan,), chunktype=numpy.ndarray>

# %%
def numpyNonZeroColumnWise(
    temps: np.ndarray,
    surfaceTemps: np.ndarray,
    thresholdTemperatureDifference: float,
    z: np.ndarray,
):
    condition = temps < (surfaceTemps - thresholdTemperatureDifference)
    mldIndex = np.array(
        [condition[:, colIdx].nonzero()[0][0] for colIdx in range(temps.shape[1])]
    )
    mldDepth = np.array([z[idx] for idx in mldIndex])[:, np.newaxis]
    mldDepth = z[mldIndex][:, np.newaxis]
    mldTemp = np.array([temps[idx, colIdx] for colIdx, idx in enumerate(mldIndex)])[
        :, np.newaxis
    ]
    return mldDepth, mldTemp

mldnumpyNonZeroColumnWise, numpymldTempNonZeroColumnWise = numpyNonZeroColumnWise(
    temps=temps, surfaceTemps=surfaceTemps, thresholdTemperatureDifference=0.1, z=z
)

# %%
mldnumpyNonZeroColumnWise, numpymldTempNonZeroColumnWise = numpyNonZeroColumnWise(    temps=tempsDask, surfaceTemps=surfaceTempsDask, thresholdTemperatureDifference=0.1, z=z)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/dask/array/core.py:1786, in Array.__float__(self)
#    1785 def __float__(self):
# -> 1786     return self._scalarfunc(float)
#
# File /usr/local/lib/python3.9/site-packages/dask/array/core.py:1778, in Array._scalarfunc(self, cast_type)
#    1777 else:
# -> 1778     return cast_type(self.compute())
#
# File /usr/local/lib/python3.9/site-packages/dask/base.py:288, in DaskMethodsMixin.compute(self, **kwargs)
#     265 """Compute this dask collection
#     266
#     267 This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     286 dask.base.compute
#     287 """
# --> 288 (result,) = compute(self, traverse=False, **kwargs)
#     289 return result
#
# File /usr/local/lib/python3.9/site-packages/dask/base.py:571, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     569     postcomputes.append(x.__dask_postcompute__())
# --> 571 results = schedule(dsk, keys, **kwargs)
#     572 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /usr/local/lib/python3.9/site-packages/dask/threaded.py:79, in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77         pool = MultiprocessingPoolExecutor(pool)
# ---> 79 results = get_async(
#      80     pool.submit,
#      81     pool._max_workers,
#      82     dsk,
#      83     result,
#      84     cache=cache,
#      85     get_id=_thread_get_id,
#      86     pack_exception=pack_exception,
#      87     **kwargs,
#      88 )
#      90 # Cleanup pools associated to dead threads
#
# File /usr/local/lib/python3.9/site-packages/dask/local.py:496, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     495 fire_tasks(chunksize)
# --> 496 for key, res_info, failed in queue_get(queue).result():
#     497     if failed:
#
# File /usr/local/lib/python3.9/site-packages/dask/local.py:134, in queue_get(q)
#     133 def queue_get(q):
# --> 134     return q.get()
#
# File /usr/local/lib/python3.9/queue.py:171, in Queue.get(self, block, timeout)
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#
# File /usr/local/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     311 if timeout is None:
# --> 312     waiter.acquire()
#     313     gotit = True
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 mldnumpyNonZeroColumnWise, numpymldTempNonZeroColumnWise = numpyNonZeroColumnWise(    temps=tempsDask, surfaceTemps=surfaceTempsDask, thresholdTemperatureDifference=0.1, z=z)
#
# Input In [31], in numpyNonZeroColumnWise(temps, surfaceTemps, thresholdTemperatureDifference, z)
#      12 mldDepth = np.array([z[idx] for idx in mldIndex])[:, np.newaxis]
#      13 mldDepth = z[mldIndex][:, np.newaxis]
# ---> 14 mldTemp = np.array([temps[idx, colIdx] for colIdx, idx in enumerate(mldIndex)])[
#      15     :, np.newaxis
#      16 ]
#      17 return mldDepth, mldTemp
#
# ValueError: setting an array element with a sequence.

# %%
def createVisualisationDataframes(df:pd.DataFrame,mlDepth:np.ndarray,mldTemp:np.ndarray):
    meltDf = pd.melt(
        pd.concat([
            df.iloc[:,[0]],
            df.iloc[:,1:].sample(10,axis=1).drop(columns=['z'],errors='ignore')],axis=1),id_vars=['z'])
    mldDf = pd.DataFrame(np.hstack([mlDepth,mldTemp]),index=df.columns[1:],columns=["mld","mldTemp"]).reset_index()
    return meltDf,mldDf
meltDf,mldDf = createVisualisationDataframes(df=df,mlDepth=mldnumpyNonZeroColumnWise,mldTemp=numpymldTempNonZeroColumnWise)

# %%
sampleQueries = meltDf.variable.sample(5)
tempLines = alt.Chart(meltDf.loc[meltDf.variable.isin(sampleQueries)],
                      title="Sample temperature profiles (lines) with predicted mixed layer depth (circles)").mark_line().encode(
    x=alt.X('value:Q',title="Temperature"),
    y=alt.Y('z:Q',title="Depth (m)"),
    color=alt.Color('variable:N',title="Profile number and date"))
mldSpots = alt.Chart(mldDf.loc[mldDf.loc[:,'index'].isin(sampleQueries)]).mark_circle(size=100).encode(
    x="mldTemp:Q",
    y="mld:Q",
    color="index:N")
alt.layer(*(tempLines,mldSpots))
# Out:
# alt.LayerChart(...)

# %%
# %timeit -n 1 -r 5 (temps<surfaceTemps-thresholdTemperatureDifference)
# %timeit -n 1 -r 5 (tempsC<surfaceTemps-thresholdTemperatureDifference)
# %timeit -n 1 -r 5 (tempsC<surfaceTempsC-thresholdTemperatureDifference)
# Out:
# 95.2 ms ± 47.6 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)
# 54.8 ms ± 8.23 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)
# 49.5 ms ± 10.8 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
# %timeit -n 1 -r 5 ne.evaluate("(temps<surfaceTemps-thresholdTemperatureDifference)")
# %timeit -n 1 -r 5 ne.evaluate("tempsC<surfaceTemps-thresholdTemperatureDifference")
# %timeit -n 1 -r 5 ne.evaluate("tempsC<surfaceTempsC-thresholdTemperatureDifference")
# Out:
# 58.6 ms ± 10.6 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)
# 34.2 ms ± 4.45 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)
# 35.1 ms ± 3.91 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
def numExprNonZeroColumnWise(
    temps: np.ndarray,
    surfaceTemps: np.ndarray,
    thresholdTemperatureDifference: float,
    z: np.ndarray,
):
    condition = ne.evaluate("temps<surfaceTemps-thresholdTemperatureDifference")
    mldIndex = np.array(
        [condition[:, colIdx].nonzero()[0][0] for colIdx in range(temps.shape[1])]
    )
    mldDepth = np.array([z[idx] for idx in mldIndex])[:, np.newaxis]
    mldDepth = z[mldIndex][:, np.newaxis]
    mldTemp = np.array([temps[idx, colIdx] for colIdx, idx in enumerate(mldIndex)])[
        :, np.newaxis
    ]
    return mldDepth, mldTemp


mldnumExprNonZeroColumnWise, numExprmldTempNonZeroColumnWise = numExprNonZeroColumnWise(
    temps=temps, surfaceTemps=surfaceTemps, thresholdTemperatureDifference=0.1, z=z
)
mldnumExprNonZeroColumnWise
np.testing.assert_array_almost_equal(
    mldnumpyNonZeroColumnWise, mldnumExprNonZeroColumnWise
)
np.testing.assert_array_almost_equal(
    numpymldTempNonZeroColumnWise, numExprmldTempNonZeroColumnWise
)

# %%
@numba.njit()
def numbaConditionLoop(
    temps: np.ndarray,
    surfaceTemps: np.ndarray,
    thresholdTemperatureDifference: float,
    z: np.ndarray,
):
    mlDepth = np.empty_like(surfaceTemps)
    mldTemp = np.empty_like(surfaceTemps)
    for col in range(temps.shape[1]):
        row = 0
        temperature = temps[row, col]
        surfaceTemp = surfaceTemps[col]
        threshold = surfaceTemp - thresholdTemperatureDifference
        while (temperature > threshold) and row < temps.shape[0]:
            row += 1
            temperature = temps[row, col]
        mlDepth[col] = z[int(row)]
        mldTemp[col] = temps[int(row), col]
    return mlDepth, mldTemp


@numba.njit(parallel=True)
def numbaConditionLoopParallel(
    temps: np.ndarray,
    surfaceTemps: np.ndarray,
    thresholdTemperatureDifference: float,
    z: np.ndarray,
):
    mlDepth = np.empty((surfaceTemps.shape[0],1))
    mldTemp = np.empty((surfaceTemps.shape[0],1))
    for col in numba.prange(temps.shape[1]):
        row = 0
        temperature = temps[row, col]
        surfaceTemp = surfaceTemps[col]
        threshold = surfaceTemp - thresholdTemperatureDifference
        while (temperature > threshold) and row < temps.shape[0]:
            row += 1
            temperature = temps[row, col]
        mlDepth[col] = z[int(row)]
        mldTemp[col] = temps[int(row), col]
    return mlDepth, mldTemp

mldnumbaConditionLoop, mldTempnumbaConditionLoop = numbaConditionLoop(
    temps=temps, surfaceTemps=surfaceTemps, thresholdTemperatureDifference=0.1, z=z
)
(
    mldnumbaConditionLoopParallel,
    mldTempnumbaConditionLoopParallel,
) = numbaConditionLoopParallel(
    temps=temps, surfaceTemps=surfaceTemps, thresholdTemperatureDifference=0.1, z=z
)
np.testing.assert_array_almost_equal(
    mldnumpyNonZeroColumnWise, mldnumExprNonZeroColumnWise
)
np.testing.assert_array_almost_equal(
    numpymldTempNonZeroColumnWise, numExprmldTempNonZeroColumnWise
)

# %%
temps32 = temps.astype(np.float32)

# %%
printmd("**Numpy**")
# %timeit -n 1 -r 3 numpyNonZeroColumnWise(temps=temps,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)
printmd("**Dask Array**")
# %timeit -n 1 -r 3 numpyNonZeroColumnWise(temps=tempsDask,surfaceTemps=surfaceTempsDask,thresholdTemperatureDifference=0.1,z=z)
printmd("**numExpr**")
# %timeit -n 1 -r 3 numExprNonZeroColumnWise(temps=temps,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)
printmd("**numExpr 32-bit**")
# %timeit -n 1 -r 3 numExprNonZeroColumnWise(temps=temps32,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)
printmd("**Numba loop (serial)**")
# %timeit -n 1 -r 3 numbaConditionLoop(temps=temps,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)
printmd("**Numba loop (parallel)**")
# %timeit -n 1 -r 3 numbaConditionLoopParallel(temps=temps,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)
# Out:
# **Numpy**
# 532 ms ± 79.9 ms per loop (mean ± std. dev. of 3 runs, 1 loop each)
# **Dask Array**
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       2 get_ipython().run_line_magic('timeit', '-n 1 -r 3 numpyNonZeroColumnWise(temps=temps,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)')
#       3 printmd("**Dask Array**")
# ----> 4 get_ipython().run_line_magic('timeit', '-n 1 -r 3 numpyNonZeroColumnWise(temps=tempsDask,surfaceTemps=surfaceTempsDask,thresholdTemperatureDifference=0.1,z=z)')
#       5 printmd("**numExpr**")
#       6 get_ipython().run_line_magic('timeit', '-n 1 -r 3 numExprNonZeroColumnWise(temps=temps,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)')
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2264, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2262     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2263 with self.builtin_trap:
# -> 2264     result = fn(*args, **kwargs)
#    2265 return result
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/magics/execution.py:1166, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1163         if time_number >= 0.2:
#    1164             break
# -> 1166 all_runs = timer.repeat(repeat, number)
#    1167 best = min(all_runs) / number
#    1168 worst = max(all_runs) / number
#
# File /usr/local/lib/python3.9/timeit.py:205, in Timer.repeat(self, repeat, number)
#     203 r = []
#     204 for i in range(repeat):
# --> 205     t = self.timeit(number)
#     206     r.append(t)
#     207 return r
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/magics/execution.py:156, in Timer.timeit(self, number)
#     154 gc.disable()
#     155 try:
# --> 156     timing = self.inner(it, self.timer)
#     157 finally:
#     158     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# Input In [22], in numpyNonZeroColumnWise(temps, surfaceTemps, thresholdTemperatureDifference, z)
#       1 def numpyNonZeroColumnWise(
#       2     temps: np.ndarray,
#       3     surfaceTemps: np.ndarray,
#       4     thresholdTemperatureDifference: float,
#       5     z: np.ndarray,
#       6 ):
#       7     condition = temps < (surfaceTemps - thresholdTemperatureDifference)
#       8     mldIndex = np.array(
# ----> 9         [condition[:, colIdx].nonzero()[0][0] for colIdx in range(temps.shape[1])]
#      10     )
#      11     mldDepth = np.array([z[idx] for idx in mldIndex])[:, np.newaxis]
#      12     mldDepth = z[mldIndex][:, np.newaxis]
#
# Input In [22], in <listcomp>(.0)
#       1 def numpyNonZeroColumnWise(
#       2     temps: np.ndarray,
#       3     surfaceTemps: np.ndarray,
#       4     thresholdTemperatureDifference: float,
#       5     z: np.ndarray,
#       6 ):
#       7     condition = temps < (surfaceTemps - thresholdTemperatureDifference)
#       8     mldIndex = np.array(
# ----> 9         [condition[:, colIdx].nonzero()[0][0] for colIdx in range(temps.shape[1])]
#      10     )
#      11     mldDepth = np.array([z[idx] for idx in mldIndex])[:, np.newaxis]
#      12     mldDepth = z[mldIndex][:, np.newaxis]
#
# File /usr/local/lib/python3.9/site-packages/dask/array/core.py:1891, in Array.__getitem__(self, index)
#    1888     return self
#    1890 out = "getitem-" + tokenize(self, index2)
# -> 1891 dsk, chunks = slice_array(out, self.name, self.chunks, index2, self.itemsize)
#    1893 graph = HighLevelGraph.from_collections(out, dsk, dependencies=[self])
#    1895 meta = meta_from_array(self._meta, ndim=len(chunks))
#
# File /usr/local/lib/python3.9/site-packages/dask/array/slicing.py:174, in slice_array(out_name, in_name, blockdims, index, itemsize)
#     171 index += (slice(None, None, None),) * missing
#     173 # Pass down to next function
# --> 174 dsk_out, bd_out = slice_with_newaxes(out_name, in_name, blockdims, index, itemsize)
#     176 bd_out = tuple(map(tuple, bd_out))
#     177 return dsk_out, bd_out
#
# File /usr/local/lib/python3.9/site-packages/dask/array/slicing.py:196, in slice_with_newaxes(out_name, in_name, blockdims, index, itemsize)
#     193         where_none[i] -= n
#     195 # Pass down and do work
# --> 196 dsk, blockdims2 = slice_wrap_lists(out_name, in_name, blockdims, index2, itemsize)
#     198 if where_none:
#     199     expand = expander(where_none)
#
# File /usr/local/lib/python3.9/site-packages/dask/array/slicing.py:252, in slice_wrap_lists(out_name, in_name, blockdims, index, itemsize)
#     250 # No lists, hooray! just use slice_slices_and_integers
#     251 if not where_list:
# --> 252     return slice_slices_and_integers(out_name, in_name, blockdims, index)
#     254 # Replace all lists with full slices  [3, 1, 0] -> slice(None, None, None)
#     255 index_without_list = tuple(
#     256     slice(None, None, None) if is_arraylike(i) else i for i in index
#     257 )
#
# File /usr/local/lib/python3.9/site-packages/dask/array/slicing.py:301, in slice_slices_and_integers(out_name, in_name, blockdims, index)
#     299 for dim, ind in zip(shape, index):
#     300     if np.isnan(dim) and ind != slice(None, None, None):
# --> 301         raise ValueError(
#     302             f"Arrays chunk sizes are unknown: {shape}{unknown_chunk_message}"
#     303         )
#     305 assert all(isinstance(ind, (slice, Integral)) for ind in index)
#     306 assert len(index) == len(blockdims)
#
# ValueError: Arrays chunk sizes are unknown: (nan,)
#
# A possible solution: https://docs.dask.org/en/latest/array-chunks.html#unknown-chunks
# Summary: to compute chunks sizes, use
#
#    x.compute_chunk_sizes()  # for Dask Array `x`
#    ddf.to_dask_array(lengths=True)  # for Dask DataFrame `ddf`

# %%
meltDf,mldDf = createVisualisationDataframes(df=df,mlDepth=mldnumbaConditionLoopParallel,mldTemp=mldTempnumbaConditionLoopParallel)
sampleQueries = meltDf.variable.sample(5)
tempLines = alt.Chart(meltDf.loc[meltDf.variable.isin(sampleQueries)]).mark_line().encode(
    x=alt.X('value:Q',title="Temperature"),
    y=alt.Y('z:Q',title="Depth (m)"),
    color=alt.Color('variable:N',title="Profile date"))
mldSpots = alt.Chart(mldDf.loc[mldDf.loc[:,'index'].isin(sampleQueries)]).mark_circle(size=100).encode(
    x="mldTemp:Q",
    y="mld:Q",
    color="index:N")
alt.layer(*(tempLines,mldSpots))
# Out:
# alt.LayerChart(...)

# %%
# %lprun -f numExprNonZeroColumnWise numExprNonZeroColumnWise(temps=temps,surfaceTemps=surfaceTemps,thresholdTemperatureDifference=0.1,z=z)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.977527 s
# File: /tmp/ipykernel_3080/212628625.py
# Function: numExprNonZeroColumnWise at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def numExprNonZeroColumnWise(
#      2                                               temps: np.ndarray,
#      3                                               surfaceTemps: np.ndarray,
#      4                                               thresholdTemperatureDifference: float,
#      5                                               z: np.ndarray,
#      6                                           ):
#      7         1      83519.0  83519.0      8.5      condition = ne.evaluate("temps<surfaceTemps-thresholdTemperatureDifference")
#      8         2      12966.0   6483.0      1.3      mldIndex = np.array(
#      9         1     562702.0 562702.0     57.6          [condition[:, colIdx].nonzero()[0][0] for colIdx in range(temps.shape[1])]
#     10                                               )
#     11         1     139125.0 139125.0     14.2      mldDepth = np.array([z[idx] for idx in mldIndex])[:, np.newaxis]
#     12         1        444.0    444.0      0.0      mldDepth = z[mldIndex][:, np.newaxis]
#     13         2     178747.0  89373.5     18.3      mldTemp = np.array([temps[idx, colIdx] for colIdx, idx in enumerate(mldIndex)])[
#     14         1         14.0     14.0      0.0          :, np.newaxis
#     15                                               ]
#     16         1         10.0     10.0      0.0      return mldDepth, mldTemp

# %%
sampleQueries = meltDf.variable.sample(5)
tempLines = alt.Chart(meltDf.loc[meltDf.variable.isin(sampleQueries)]).mark_line().encode(
    x='value:Q',
    y='z:Q',
    color='variable:N')
mldSpots = alt.Chart(mldDf.loc[mldDf.loc[:,'index'].isin(sampleQueries)]).mark_circle(size=100).encode(
    x="mldTemp:Q",
    y="mld:Q",
    color="index:N")
alt.layer(*(tempLines,mldSpots))
# Out:
# alt.LayerChart(...)
